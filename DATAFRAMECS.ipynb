# %% [markdown]
# <a href="https://colab.research.google.com/github/geo-filho/dataframeCS2/blob/main/DATAFRAMECS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Criando um DataFrame vazio e importando a biblioteca
import pandas as pd
df = pd.DataFrame()

# %%
# Adicionando NaVi

navi = {
    'Nome': ['Aleksi Virolainen', 'Valerij Vakhovsjkyj', 'Justinas Lekavicius', 'Mihai Ivan', 'Ihor Zhdanov'],
    'Nick em jogo': ['Aleksib', 'b1t', 'jL', 'iM', 'w0nderful'],
    'Idade': [27, 21, 24, 24, 19],
    'Quantidade de títulos': [3, 11, 1, 1, 1],
    'Nacionalidade': ['Finlândia', 'Ucrânia', 'Lituânia', 'Romênia', 'Ucrânia'],
    'Função em game': ['In-game leader', 'Rifler(support)', 'Rifler(lurker)', 'Rifler(entry fragger)', 'AWPer']
}

# Criar DataFrame para NaVi
df_navi = pd.DataFrame(navi)


# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                   Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0    Aleksi Virolainen      Aleksib     27                      3
# 1  Valerij Vakhovsjkyj          b1t     21                     11
# 2  Justinas Lekavicius           jL     24                      1
# 3           Mihai Ivan           iM     24                      1
# 4         Ihor Zhdanov    w0nderful     19                      1
#
#   Nacionalidade         Função em game
# 0     Finlândia         In-game leader
# 1       Ucrânia        Rifler(support)
# 2      Lituânia         Rifler(lurker)
# 3       Romênia  Rifler(entry fragger)
# 4       Ucrânia                  AWPer

# %%
# Criar dicionário para a Faze
faze = {
    'Nome': ['Håvard Nygaard', 'Helvijs Saukants', 'Finn Andersen', 'Robin Kool', 'David Čerňanský'],
    'Nick em jogo': ['rain', 'broky', 'karrigan', 'ropz', 'frozen'],
    'Idade': [29, 23, 34, 24, 21],
    'Quantidade de títulos': [21, 11, 26, 19, 7],
    'Nacionalidade': ['Noruega', 'Letônia', 'Dinamarca', 'Estônia', 'Eslováquia'],
    'Função em game': ['Rifler', 'AWPer', 'In-game Leader', 'Rifler(lurker)', 'Rifler']
}

# Criar DataFrame para a Faze
df_faze = pd.DataFrame(faze)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                   Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0    Aleksi Virolainen      Aleksib     27                      3
# 1  Valerij Vakhovsjkyj          b1t     21                     11
# 2  Justinas Lekavicius           jL     24                      1
# 3           Mihai Ivan           iM     24                      1
# 4         Ihor Zhdanov    w0nderful     19                      1
# 5       Håvard Nygaard         rain     29                     21
# 6     Helvijs Saukants        broky     23                     11
# 7        Finn Andersen     karrigan     34                     26
# 8           Robin Kool         ropz     24                     19
# 9      David Čerňanský       frozen     21                      7
#
#   Nacionalidade         Função em game
# 0     Finlândia         In-game leader
# 1       Ucrânia        Rifler(support)
# 2      Lituânia         Rifler(lurker)
# 3       Romênia  Rifler(entry fragger)
# 4       Ucrânia                  AWPer
# ...

# %%
# Criar dicionário para a Mouz
mouz = {
    'Nome': ['Ádám Torzsás', 'Dorian Berman', 'Kamil  Szkaradek ', 'Jimi  Salo ', 'Ludvig  Brolin'],
    'Nick em jogo': ['torzsi', 'xertioN', 'siuhy', 'Jimpphat', 'Brollan'],
    'Idade': [21, 19, 21, 17, 21],
    'Quantidade de títulos': [2, 2, 2, 2, 3],
    'Nacionalidade': ['Hungria', 'Israel', 'Polônia', 'Finlândia', 'Suécia'],
    'Função em game': ['AWPer', 'Rifler (entry fragger)', 'In-game Leader', 'Rifler', 'Rifler (entry fragger)']
}

# Criar DataFrame para a Mouz
df_mouz = pd.DataFrame(mouz)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                    Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0     Aleksi Virolainen      Aleksib     27                      3
# 1   Valerij Vakhovsjkyj          b1t     21                     11
# 2   Justinas Lekavicius           jL     24                      1
# 3            Mihai Ivan           iM     24                      1
# 4          Ihor Zhdanov    w0nderful     19                      1
# 5        Håvard Nygaard         rain     29                     21
# 6      Helvijs Saukants        broky     23                     11
# 7         Finn Andersen     karrigan     34                     26
# 8            Robin Kool         ropz     24                     19
# 9       David Čerňanský       frozen     21                      7
# 10         Ádám Torzsás       torzsi     21                      2
# 11        Dorian Berman      xertioN     19                      2
# 12    Kamil  Szkaradek         siuhy     21                      2
# ...

# %%
# Criar dicionário para a Spirit
spirit = {
    'Nome': ['Leonid Vishnyakov', 'Dmitriy Sokolov', 'Boris Vorobyev', 'Myroslav Plakhotja', 'Danil Kryshkovets'],
    'Nick em jogo': ['chopper', 'sh1ro', 'magixx', 'zont1x', 'donk'],
    'Idade': [27, 22, 20, 18, 17],
    'Quantidade de títulos': [2, 9, 2, 2, 2],
    'Nacionalidade': ['Rússia', 'Rússia', 'Rússia', 'Ucrânia', 'Rússia'],
    'Função em game': ['In-game leader', 'AWPer', 'Rifler (lurker)', 'Rifler', 'Rifler (entry fragger)']
}

# Criar DataFrame para a Spirit
df_spirit = pd.DataFrame(spirit)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                    Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0     Aleksi Virolainen      Aleksib     27                      3
# 1   Valerij Vakhovsjkyj          b1t     21                     11
# 2   Justinas Lekavicius           jL     24                      1
# 3            Mihai Ivan           iM     24                      1
# 4          Ihor Zhdanov    w0nderful     19                      1
# 5        Håvard Nygaard         rain     29                     21
# 6      Helvijs Saukants        broky     23                     11
# 7         Finn Andersen     karrigan     34                     26
# 8            Robin Kool         ropz     24                     19
# 9       David Čerňanský       frozen     21                      7
# 10         Ádám Torzsás       torzsi     21                      2
# 11        Dorian Berman      xertioN     19                      2
# 12    Kamil  Szkaradek         siuhy     21                      2
# ...

# %%
# Criar dicionário para a G2
G2 = {
    'Nome': ['Nikola Kovač', 'Nemanja Kovač', 'Nemanja Isaković', 'Rasmus Nielsen', 'Ilya Osipov'],
    'Nick em jogo': ['NiKo', 'huNter', 'nexa', 'HooXi', 'm0NESY'],
    'Idade': [27, 28, 27, 28, 19],
    'Quantidade de títulos': [14, 3, 1, 3, 3],
    'Nacionalidade': ['Bósnia e Herzegovina', 'Bósnia e Herzegovina', 'Sérvia', 'Dinamarca', 'Rússia'],
    'Função em game': ['Rifler (entry fragger)', 'Rifler (lurker)', 'Rifler (support)', 'In-game leader', 'AWPer']
}

# Criar DataFrame para a G2
df_G2 = pd.DataFrame(G2)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                    Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0     Aleksi Virolainen      Aleksib     27                      3
# 1   Valerij Vakhovsjkyj          b1t     21                     11
# 2   Justinas Lekavicius           jL     24                      1
# 3            Mihai Ivan           iM     24                      1
# 4          Ihor Zhdanov    w0nderful     19                      1
# 5        Håvard Nygaard         rain     29                     21
# 6      Helvijs Saukants        broky     23                     11
# 7         Finn Andersen     karrigan     34                     26
# 8            Robin Kool         ropz     24                     19
# 9       David Čerňanský       frozen     21                      7
# 10         Ádám Torzsás       torzsi     21                      2
# 11        Dorian Berman      xertioN     19                      2
# 12    Kamil  Szkaradek         siuhy     21                      2
# ...

# %%
# Criar dicionário para a vitality
vitality = {
    'Nome': ['Dan Madesclaire', 'Mathieu Herbaut', 'Shahar Shushan', 'Lotan Giladi', 'William Merriman'],
    'Nick em jogo': ['apEX', 'ZywOo', 'flameZ', 'Spinx', 'mezii'],
    'Idade': [31, 23, 20, 23, 25],
    'Quantidade de títulos': [24, 12, 3, 6, 2],
    'Nacionalidade': ['França', 'França', 'Israel', 'Israel', 'Inglaterra'],
    'Função em game': ['In-game leader', 'AWPer', 'Rifler (entry fragger)', 'Rifler (lurker)', 'Rifler']
}

# Criar DataFrame para a vitality
df_vitality = pd.DataFrame(vitality)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2, df_vitality], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                    Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0     Aleksi Virolainen      Aleksib     27                      3
# 1   Valerij Vakhovsjkyj          b1t     21                     11
# 2   Justinas Lekavicius           jL     24                      1
# 3            Mihai Ivan           iM     24                      1
# 4          Ihor Zhdanov    w0nderful     19                      1
# 5        Håvard Nygaard         rain     29                     21
# 6      Helvijs Saukants        broky     23                     11
# 7         Finn Andersen     karrigan     34                     26
# 8            Robin Kool         ropz     24                     19
# 9       David Čerňanský       frozen     21                      7
# 10         Ádám Torzsás       torzsi     21                      2
# 11        Dorian Berman      xertioN     19                      2
# 12    Kamil  Szkaradek         siuhy     21                      2
# ...

# %%
# Criar dicionário para a eternal fire
eternalfire = {
    'Nome': ['Engin Küpeli', 'İsmailсan Dörtkardeş', 'Özgür Eker', 'Buğra Arkın', 'Ali Haydar'],
    'Nick em jogo': ['MAJ3R', 'XANTARES', 'woxic', 'Calyx', 'Wicadia'],
    'Idade': [33, 28, 25, 25, 19],
    'Quantidade de títulos': [0, 4, 3, 0, 0],
    'Nacionalidade': ['Turquia', 'Turquia', 'Turquia', 'Turquia', 'Turquia'],
    'Função em game': ['In-game leader', 'Rifler', 'AWPer', 'Rifler (support)', 'Rifler']
}

# Criar DataFrame para a eternal fire
df_eternalfire = pd.DataFrame(eternalfire)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2, df_vitality, df_eternalfire], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                     Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0      Aleksi Virolainen      Aleksib     27                      3
# 1    Valerij Vakhovsjkyj          b1t     21                     11
# 2    Justinas Lekavicius           jL     24                      1
# 3             Mihai Ivan           iM     24                      1
# 4           Ihor Zhdanov    w0nderful     19                      1
# 5         Håvard Nygaard         rain     29                     21
# 6       Helvijs Saukants        broky     23                     11
# 7          Finn Andersen     karrigan     34                     26
# 8             Robin Kool         ropz     24                     19
# 9        David Čerňanský       frozen     21                      7
# 10          Ádám Torzsás       torzsi     21                      2
# 11         Dorian Berman      xertioN     19                      2
# 12     Kamil  Szkaradek         siuhy     21                      2
# ...

# %%
# Criar dicionário para a astralis
astralis = {
    'Nome': ['Nicolai Reedtz', 'Martin Lund', 'Alexander Bro', 'Jakob Nygaard', 'Victor Staehr'],
    'Nick em jogo': ['dev1ce', 'stavn', 'br0', 'jabbi', 'Staehr'],
    'Idade': [28, 22, 22, 20, 19],
    'Quantidade de títulos': [30, 6, 1, 2, 0],
    'Nacionalidade': ['Dinamarca', 'Dinamarca', 'Dinamarca', 'Dinamarca', 'Dinamarca'],
    'Função em game': ['In-game leader', 'Rifler', 'Rifler', 'Rifler', 'Rifler']
}

# Criar DataFrame para a astralis
df_astralis = pd.DataFrame(astralis)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2, df_vitality, df_eternalfire, df_astralis], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                     Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0      Aleksi Virolainen      Aleksib     27                      3
# 1    Valerij Vakhovsjkyj          b1t     21                     11
# 2    Justinas Lekavicius           jL     24                      1
# 3             Mihai Ivan           iM     24                      1
# 4           Ihor Zhdanov    w0nderful     19                      1
# 5         Håvard Nygaard         rain     29                     21
# 6       Helvijs Saukants        broky     23                     11
# 7          Finn Andersen     karrigan     34                     26
# 8             Robin Kool         ropz     24                     19
# 9        David Čerňanský       frozen     21                      7
# 10          Ádám Torzsás       torzsi     21                      2
# 11         Dorian Berman      xertioN     19                      2
# 12     Kamil  Szkaradek         siuhy     21                      2
# ...

# %%
# Criar dicionário para a virtuspro
virtuspro = {
    'Nome': ['Denis Sharipov', 'Evgeniy Lebedev', 'Dzhami Ali', 'David Daniyelyan', 'Petr Bolyshev'],
    'Nick em jogo': ['electroNic', 'FL1T', 'Jame', 'n0rb3r7', 'fame'],
    'Idade': [25, 23, 25, 23, 21],
    'Quantidade de títulos': [17, 2, 5, 2, 2],
    'Nacionalidade': ['Rússia', 'Rússia', 'Rússia', 'Rússia', 'Rússia'],
    'Função em game': ['Rifler', 'Rifler (lurker)', 'In-game leader', 'Rifler', 'Rifler']
}

# Criar DataFrame para a virtuspro
df_virtuspro = pd.DataFrame(virtuspro)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2, df_vitality, df_eternalfire, df_astralis, df_virtuspro], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                     Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0      Aleksi Virolainen      Aleksib     27                      3
# 1    Valerij Vakhovsjkyj          b1t     21                     11
# 2    Justinas Lekavicius           jL     24                      1
# 3             Mihai Ivan           iM     24                      1
# 4           Ihor Zhdanov    w0nderful     19                      1
# 5         Håvard Nygaard         rain     29                     21
# 6       Helvijs Saukants        broky     23                     11
# 7          Finn Andersen     karrigan     34                     26
# 8             Robin Kool         ropz     24                     19
# 9        David Čerňanský       frozen     21                      7
# 10          Ádám Torzsás       torzsi     21                      2
# 11         Dorian Berman      xertioN     19                      2
# 12     Kamil  Szkaradek         siuhy     21                      2
# ...

# %%
# Criar dicionário para a heroic
heroic = {
    'Nome': ['Guy Iluz', 'René Madsen', 'Rasmus Beck', 'Abdulkhalik Gasanov', 'Damjan Stoilkovski'],
    'Nick em jogo': ['NertZ', 'TeSeS', 'sjuush', 'degster', 'kyxsan'],
    'Idade': [24, 23, 25, 22, 23],
    'Quantidade de títulos': [1, 6, 5, 0, 0],
    'Nacionalidade': ['Israel', 'Dinamarca', 'Dinamarca', 'Rússia', 'Macedônia do Norte'],
    'Função em game': ['Rifler', 'In-game leader', 'Rifler (support)', 'AWPer', 'In-game leader']
}

# Criar DataFrame para a heroic
df_heroic = pd.DataFrame(heroic)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2, df_vitality, df_eternalfire, df_astralis, df_virtuspro, df_heroic], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                     Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0      Aleksi Virolainen      Aleksib     27                      3
# 1    Valerij Vakhovsjkyj          b1t     21                     11
# 2    Justinas Lekavicius           jL     24                      1
# 3             Mihai Ivan           iM     24                      1
# 4           Ihor Zhdanov    w0nderful     19                      1
# 5         Håvard Nygaard         rain     29                     21
# 6       Helvijs Saukants        broky     23                     11
# 7          Finn Andersen     karrigan     34                     26
# 8             Robin Kool         ropz     24                     19
# 9        David Čerňanský       frozen     21                      7
# 10          Ádám Torzsás       torzsi     21                      2
# 11         Dorian Berman      xertioN     19                      2
# 12     Kamil  Szkaradek         siuhy     21                      2
# ...

# %%
# Criar dicionário para a complexity
complexity = {
    'Nome': ['Jonathan Jablonowski', 'Ioannis Theodosiou', 'Ricky Kemery', 'Håkon Fjærli', 'Michael Wince'],
    'Nick em jogo': ['EliGE', 'JT', 'floppy', 'hallzerk', 'Grim'],
    'Idade': [26, 25, 24, 23, 23],
    'Quantidade de títulos': [10, 0, 0, 0, 0],
    'Nacionalidade': ['Estados Unidos', 'África do Sul', 'Estados Unidos', 'Noruega', 'Estados Unidos'],
    'Função em game': ['Rifler', 'In-game leader', 'Rifler', 'AWPer', 'Rifler (entry fragger)']
}

# Criar DataFrame para a complexity
df_complexity = pd.DataFrame(complexity)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2, df_vitality, df_eternalfire, df_astralis, df_virtuspro, df_heroic, df_complexity], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                     Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0      Aleksi Virolainen      Aleksib     27                      3
# 1    Valerij Vakhovsjkyj          b1t     21                     11
# 2    Justinas Lekavicius           jL     24                      1
# 3             Mihai Ivan           iM     24                      1
# 4           Ihor Zhdanov    w0nderful     19                      1
# 5         Håvard Nygaard         rain     29                     21
# 6       Helvijs Saukants        broky     23                     11
# 7          Finn Andersen     karrigan     34                     26
# 8             Robin Kool         ropz     24                     19
# 9        David Čerňanský       frozen     21                      7
# 10          Ádám Torzsás       torzsi     21                      2
# 11         Dorian Berman      xertioN     19                      2
# 12     Kamil  Szkaradek         siuhy     21                      2
# ...

# %%
# Criar dicionário para a falcons
falcons = {
    'Nome': ['Marco Pfeiffer', 'Peter Rasmussen', 'Emil Reif', 'Pavle Bošković', 'Alvaro Garcia'],
    'Nick em jogo': ['Snappi', 'dupreeh', 'Magisk', 'maden', 'SunPayus'],
    'Idade': [33, 31, 26, 25, 25],
    'Quantidade de títulos': [1, 32, 26, 1, 1],
    'Nacionalidade': ['Dinamarca', 'Dinamarca', 'Dinamarca', 'Montenegro', 'Espanha'],
    'Função em game': ['In-game leader', 'Rifler (entry fragger)', 'Rifler', 'Rifler (entry fragger)', 'AWPer']
}

# Criar DataFrame para a falcons
df_falcons = pd.DataFrame(falcons)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2, df_vitality, df_eternalfire, df_astralis, df_virtuspro, df_heroic, df_complexity, df_falcons], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                     Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0      Aleksi Virolainen      Aleksib     27                      3
# 1    Valerij Vakhovsjkyj          b1t     21                     11
# 2    Justinas Lekavicius           jL     24                      1
# 3             Mihai Ivan           iM     24                      1
# 4           Ihor Zhdanov    w0nderful     19                      1
# 5         Håvard Nygaard         rain     29                     21
# 6       Helvijs Saukants        broky     23                     11
# 7          Finn Andersen     karrigan     34                     26
# 8             Robin Kool         ropz     24                     19
# 9        David Čerňanský       frozen     21                      7
# 10          Ádám Torzsás       torzsi     21                      2
# 11         Dorian Berman      xertioN     19                      2
# 12     Kamil  Szkaradek         siuhy     21                      2
# ...

# %%
# Criar dicionário para a pain
pain = {
    'Nome': ['Rodrigo Bittencourt', 'Lucas Soares', 'Kaue Kaschuk', 'João Vinicius', 'Lucas Meneghini'],
    'Nick em jogo': ['biguzera', 'nqz', 'kauez', 'snow', 'lux'],
    'Idade': [27, 19, 20, 17, 22],
    'Quantidade de títulos': [0, 0, 0, 0, 0],
    'Nacionalidade': ['Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil'],
    'Função em game': ['In-game leader', 'AWPer', 'Rifler', 'Rifler', 'Rifler']
}

# Criar DataFrame para a pain
df_pain = pd.DataFrame(pain)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2, df_vitality, df_eternalfire, df_astralis, df_virtuspro, df_heroic, df_complexity, df_falcons, df_pain], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                    Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0     Aleksi Virolainen      Aleksib     27                      3
# 1   Valerij Vakhovsjkyj          b1t     21                     11
# 2   Justinas Lekavicius           jL     24                      1
# 3            Mihai Ivan           iM     24                      1
# 4          Ihor Zhdanov    w0nderful     19                      1
# ..                  ...          ...    ...                    ...
# 60  Rodrigo Bittencourt     biguzera     27                      0
# 61         Lucas Soares          nqz     19                      0
# 62         Kaue Kaschuk        kauez     20                      0
# 63        João Vinicius         snow     17                      0
# 64      Lucas Meneghini          lux     22                      0
#
#    Nacionalidade                   Função em game
# 0      Finlândia  In-game leader; rifler(support)
# 1        Ucrânia                  Rifler(support)
# ...

# %%
# Criar dicionário para a ence
ence = {
    'Nome': ['Lukas Rossander', 'Krzysztof Górski', 'Paweł Dycha', 'Aleksander Miskiewicz', 'Kacper Walukiewicz'],
    'Nick em jogo': ['gla1ve', 'Goofy', 'dycha', 'hades', 'Kylar'],
    'Idade': [28, 23, 26, 24, 24],
    'Quantidade de títulos': [24, 0, 1, 0, 0],
    'Nacionalidade': ['Dinamarca', 'Polônia', 'Polônia', 'Polônia', 'Polônia'],
    'Função em game': ['In-game leader', 'Rifler', 'Rifler', 'AWPer', 'Rifler (lurker)']
}

# Criar DataFrame para a ence
df_ence = pd.DataFrame(ence)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2, df_vitality, df_eternalfire, df_astralis, df_virtuspro, df_heroic, df_complexity, df_falcons, df_pain, df_ence], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                      Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0       Aleksi Virolainen      Aleksib     27                      3
# 1     Valerij Vakhovsjkyj          b1t     21                     11
# 2     Justinas Lekavicius           jL     24                      1
# 3              Mihai Ivan           iM     24                      1
# 4            Ihor Zhdanov    w0nderful     19                      1
# ..                    ...          ...    ...                    ...
# 65        Lukas Rossander       gla1ve     28                     24
# 66       Krzysztof Górski        Goofy     23                      0
# 67            Paweł Dycha        dycha     26                      1
# 68  Aleksander Miskiewicz        hades     24                      0
# 69     Kacper Walukiewicz        Kylar     24                      0
#
#    Nacionalidade                   Função em game
# 0      Finlândia  In-game leader; rifler(support)
# ...

# %%
# Criar dicionário para a liquid
liquid = {
    'Nome': ['Casper Møller', 'Keith Markovic', 'Russel Van Dulken', 'Mareks Gaļinskis', 'Felipe Medeiros'],
    'Nick em jogo': ['cadiaN', 'NAF', 'Twistzz', 'YEKINDAR', 'skullz'],
    'Idade': [28, 26, 24, 24, 22],
    'Quantidade de títulos': [24, 0, 1, 0, 0],
    'Nacionalidade': ['Dinamarca', 'Canadá', 'Canadá', 'Letônia', 'Brasil'],
    'Função em game': ['In-game leader', 'Rifler', 'Rifler', 'Rifler (entry fragger)', 'Rifler']
}

# Criar DataFrame para a liquid
df_liquid = pd.DataFrame(liquid)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2, df_vitality, df_eternalfire, df_astralis, df_virtuspro, df_heroic, df_complexity, df_falcons, df_pain, df_ence, df_liquid], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                    Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0     Aleksi Virolainen      Aleksib     27                      3
# 1   Valerij Vakhovsjkyj          b1t     21                     11
# 2   Justinas Lekavicius           jL     24                      1
# 3            Mihai Ivan           iM     24                      1
# 4          Ihor Zhdanov    w0nderful     19                      1
# ..                  ...          ...    ...                    ...
# 70        Casper Møller       cadiaN     28                     24
# 71       Keith Markovic          NAF     26                      0
# 72    Russel Van Dulken      Twistzz     24                      1
# 73     Mareks Gaļinskis     YEKINDAR     24                      0
# 74      Felipe Medeiros       skullz     22                      0
#
#    Nacionalidade                   Função em game
# 0      Finlândia  In-game leader; rifler(support)
# 1        Ucrânia                  Rifler(support)
# ...

# %%
# Criar dicionário para a mibr
mibr = {
    'Nome': ['Raphael Lacerda', 'Rafael Costa', 'André Abreu', 'Breno Poletto', 'Felipe Yuji'],
    'Nick em jogo': ['exit', 'saffee', 'drop', 'brnz4n', 'insani'],
    'Idade': [27, 29, 20, 20, 20],
    'Quantidade de títulos': [0, 0, 0, 0, 0],
    'Nacionalidade': ['Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil'],
    'Função em game': ['In-game leader', 'AWPer', 'Rifler', 'Rifler', 'Rifler']
}

# Criar DataFrame para a mibr
df_mibr = pd.DataFrame(mibr)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2, df_vitality, df_eternalfire, df_astralis, df_virtuspro, df_heroic, df_complexity, df_falcons, df_pain, df_ence, df_liquid, df_mibr], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                    Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0     Aleksi Virolainen      Aleksib     27                      3
# 1   Valerij Vakhovsjkyj          b1t     21                     11
# 2   Justinas Lekavicius           jL     24                      1
# 3            Mihai Ivan           iM     24                      1
# 4          Ihor Zhdanov    w0nderful     19                      1
# ..                  ...          ...    ...                    ...
# 75      Raphael Lacerda         exit     27                      0
# 76         Rafael Costa       saffee     29                      0
# 77          André Abreu         drop     20                      0
# 78        Breno Poletto       brnz4n     20                      0
# 79          Felipe Yuji       insani     20                      0
#
#    Nacionalidade                   Função em game
# 0      Finlândia  In-game leader; rifler(support)
# 1        Ucrânia                  Rifler(support)
# ...

# %%
# Criar dicionário para a imperial
imperial = {
    'Nome': ['Henrique Teles', 'João Vasconcellos', 'Vinicius Figueiredo', 'Lucas Bacelar', 'Kaiky Santos'],
    'Nick em jogo': ['HEN1', 'felps', 'VINI', 'decenty', 'noway'],
    'Idade': [28, 27, 24, 20, 19],
    'Quantidade de títulos': [5, 7, 3, 0, 0],
    'Nacionalidade': ['Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil'],
    'Função em game': ['AWPer', 'Rifler (lurker)', 'Rifler (support)', 'Rifler (lurker)', 'Rifler']
}

# Criar DataFrame para a imperial
df_imperial = pd.DataFrame(imperial)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2, df_vitality, df_eternalfire, df_astralis, df_virtuspro, df_heroic, df_complexity, df_falcons, df_pain, df_ence, df_liquid, df_mibr, df_imperial], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                    Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0     Aleksi Virolainen      Aleksib     27                      3
# 1   Valerij Vakhovsjkyj          b1t     21                     11
# 2   Justinas Lekavicius           jL     24                      1
# 3            Mihai Ivan           iM     24                      1
# 4          Ihor Zhdanov    w0nderful     19                      1
# ..                  ...          ...    ...                    ...
# 80       Henrique Teles         HEN1     28                      5
# 81    João Vasconcellos        felps     27                      7
# 82  Vinicius Figueiredo         VINI     24                      3
# 83        Lucas Bacelar      decenty     20                      0
# 84         Kaiky Santos        noway     19                      0
#
#    Nacionalidade                   Função em game
# 0      Finlândia  In-game leader; rifler(support)
# 1        Ucrânia                  Rifler(support)
# ...

# %%
# Criar dicionário para a themongolz
themongolz = {
    'Nome': ['Garidmagnai Byambasuren', 'Sodbayar Munkhbold', 'Azbayar Munkhbold', 'Ayush Batbold', 'Usukhbayar Banzragch'],
    'Nick em jogo': ['bLitz', 'Techno4K', 'Senzu', 'mzinho', '910'],
    'Idade': [22, 18, 17, 16, 21],
    'Quantidade de títulos': [0, 0, 0, 0, 0],
    'Nacionalidade': ['Mongólia', 'Mongólia', 'Mongólia', 'Mongólia', 'Mongólia'],
    'Função em game': ['In-game leader', 'Rifler', 'Rifler', 'Rifler', 'AWPer']
}

# Criar DataFrame para a themongolz
df_themongolz = pd.DataFrame(themongolz)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2, df_vitality, df_eternalfire, df_astralis, df_virtuspro, df_heroic, df_complexity, df_falcons, df_pain, df_ence, df_liquid, df_mibr, df_imperial, df_themongolz], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                        Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0         Aleksi Virolainen      Aleksib     27                      3
# 1       Valerij Vakhovsjkyj          b1t     21                     11
# 2       Justinas Lekavicius           jL     24                      1
# 3                Mihai Ivan           iM     24                      1
# 4              Ihor Zhdanov    w0nderful     19                      1
# ..                      ...          ...    ...                    ...
# 85  Garidmagnai Byambasuren        bLitz     22                      0
# 86       Sodbayar Munkhbold     Techno4K     18                      0
# 87        Azbayar Munkhbold        Senzu     17                      0
# 88            Ayush Batbold       mzinho     16                      0
# 89     Usukhbayar Banzragch          910     21                      0
#
#    Nacionalidade                   Função em game
# 0      Finlândia  In-game leader; rifler(support)
# ...

# %%
# Criar dicionário para a furia
furia = {
    'Nome': ['Gabriel Toledo', 'Marcelo Cespedes', 'Yuri Boian', 'Kaike Cerato', 'Kayke Bertolucci'],
    'Nick em jogo': ['FalleN', 'chelo', 'yuurih', 'KSCERATO', 'kye'],
    'Idade': [32, 25, 24, 24, 19],
    'Quantidade de títulos': [14, 1, 4, 4, 0],
    'Nacionalidade': ['Brasil', 'Brasil', 'Brasil', 'Brasil', 'Brasil'],
    'Função em game': ['In-game leader', 'Rifler (entry fragger)', 'Rifler', 'Rifler', 'Rifler']
}

# Criar DataFrame para a furia
df_furia = pd.DataFrame(furia)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2, df_vitality, df_eternalfire, df_astralis, df_virtuspro, df_heroic, df_complexity, df_falcons, df_pain, df_ence, df_liquid, df_mibr, df_imperial, df_themongolz, df_furia], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                    Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0     Aleksi Virolainen      Aleksib     27                      3
# 1   Valerij Vakhovsjkyj          b1t     21                     11
# 2   Justinas Lekavicius           jL     24                      1
# 3            Mihai Ivan           iM     24                      1
# 4          Ihor Zhdanov    w0nderful     19                      1
# ..                  ...          ...    ...                    ...
# 90       Gabriel Toledo       FalleN     32                     14
# 91     Marcelo Cespedes        chelo     25                      1
# 92           Yuri Boian       yuurih     24                      4
# 93         Kaike Cerato     KSCERATO     24                      4
# 94     Kayke Bertolucci          kye     19                      0
#
#    Nacionalidade                   Função em game
# 0      Finlândia  In-game leader; rifler(support)
# 1        Ucrânia                  Rifler(support)
# ...

# %%
# Criar dicionário para a flyquest
flyquest = {
    'Nome': ['Christopher Nong', 'Jay Tregillgas', 'Alistair Johnston', 'Joshua Potter', 'Declan Portelli'],
    'Nick em jogo': ['dexter', 'Liazz', 'aliStair', 'INS', 'Vexite'],
    'Idade': [29, 26, 26, 25, 19],
    'Quantidade de títulos': [1, 0, 0, 0, 0],
    'Nacionalidade': ['Austrália', 'Austrália', 'Austrália', 'Austrália', 'Austrália'],
    'Função em game': ['In-game leader', 'Rifler (lurker)', 'AWPer', 'In-game leader', 'Rifler']
}

# Criar DataFrame para a flyquest
df_flyquest = pd.DataFrame(flyquest)

# Concatenar DataFrames de diferentes times
df = pd.concat([df_navi, df_faze, df_mouz, df_spirit, df_G2, df_vitality, df_eternalfire, df_astralis, df_virtuspro, df_heroic, df_complexity, df_falcons, df_pain, df_ence, df_liquid, df_mibr, df_imperial, df_themongolz, df_furia, df_flyquest], ignore_index=True)

# Exibir DataFrame atual
print(df)
# Out:
#                    Nome Nick em jogo  Idade  Quantidade de títulos  \
# 0     Aleksi Virolainen      Aleksib     27                      3
# 1   Valerij Vakhovsjkyj          b1t     21                     11
# 2   Justinas Lekavicius           jL     24                      1
# 3            Mihai Ivan           iM     24                      1
# 4          Ihor Zhdanov    w0nderful     19                      1
# ..                  ...          ...    ...                    ...
# 95     Christopher Nong       dexter     29                      1
# 96       Jay Tregillgas        Liazz     26                      0
# 97    Alistair Johnston     aliStair     26                      0
# 98        Joshua Potter          INS     25                      0
# 99      Declan Portelli       Vexite     19                      0
#
#    Nacionalidade                   Função em game
# 0      Finlândia  In-game leader; rifler(support)
# 1        Ucrânia                  Rifler(support)
# ...

# %%
# Salvando como arquivo CSV
df.to_csv('jogadores_cs_csv.csv', index=False)

# Salvando como arquivo Excel
df.to_excel('dataframe_cs_excel.xlsx', index=False)
